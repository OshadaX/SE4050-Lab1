# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D

# %%
#task 1
array = np.random.exponential(scale=1.0, size=(4, 4))
print("Array:")
print(array)
# Out:
# Array:
# [[5.31958543 2.76750443 1.27392111 2.24719511]
#  [1.61871743 0.11577664 2.87343455 1.85279084]
#  [2.45893518 0.56647043 1.56047402 1.11756406]
#  [1.73679487 0.11775299 1.09076408 1.37743865]]

# %%
exp_data = np.random.exponential(scale=1.0, size=100000)
uniform_data = np.random.rand(100000)        # Uniform
normal_data = np.random.randn(100000)        # Normal

# Plot histograms
plt.figure(figsize=(10, 6))
plt.hist(exp_data, density=True, bins=200, histtype="step", color="red", label="Exponential")
plt.hist(uniform_data, density=True, bins=200, histtype="step", color="blue", label="Uniform")
plt.hist(normal_data, density=True, bins=200, histtype="step", color="green", label="Normal")

# Customize axis and labels
plt.axis([-2.5, 6, 0, 1.1])  # Adjusted range for better visualization
plt.legend(loc="upper right")
plt.title("Random Distributions")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()

# %%
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = X**2 + Y**2

# Plot 3D surface
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis')

# Labels and title
ax.set_title("3D Plot: Z = X² + Y²")
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")
plt.show()

# %%
data = {
    'HP': np.random.randint(20, 150, 50),
    'Attack': np.random.randint(10, 180, 50),
    'Defense': np.random.randint(10, 180, 50),
    'Sp. Atk': np.random.randint(10, 180, 50),
    'Sp. Def': np.random.randint(10, 180, 50),
    'Speed': np.random.randint(10, 180, 50)
}
df = pd.DataFrame(data)

# Calculate Pearson and Spearman correlations
pearson_corr = df.corr(method='pearson')
spearman_corr = df.corr(method='spearman')

# Plot heatmaps
plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
sns.heatmap(pearson_corr, annot=True, cmap='coolwarm')
plt.title("Pearson Correlation")

plt.subplot(1, 2, 2)
sns.heatmap(spearman_corr, annot=True, cmap='coolwarm')
plt.title("Spearman Correlation")

plt.tight_layout()
plt.show()

# %%
import os
os.listdir()
# Out:
# ['.config', 'sample_data']

# %%
from google.colab import files

uploaded = files.upload()  # Click “Choose Files” and select Au_nanoParticle_dataset.csv
# Out:
#      <input type="file" id="files-91522647-61e2-4e02-a7ad-a6b8fe9e6096" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-91522647-61e2-4e02-a7ad-a6b8fe9e6096">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
os.listdir()
# Out:
# ['.config', 'Au_nanoparticle_dataset (2).csv', 'sample_data']

# %%
filename = "Au_nanoparticle_dataset (2).csv"
df = pd.read_csv(filename)

# %%
print(df.head())
# Out:
#    ID    T       tau  time  N_total  N_bulk  N_surface        Volume    R_min  \
# 0   1  273  0.000025     1     1599    1014        585  2.710000e-26  15.5898
# 1   2  273  0.000025     2     1642    1034        608  2.780000e-26  15.3996
# 2   3  273  0.000025     3     4637    3365       1272  7.850000e-26  21.9199
# 3   4  273  0.000025     4     7189    5292       1897  1.220000e-25  23.2542
# 4   5  273  0.000025     5    11004    8508       2496  1.860000e-25  27.1200
#
#      R_max  ...  q6q6_S14  q6q6_S15  q6q6_S16  q6q6_S17  q6q6_S18  q6q6_S19  \
# 0  19.4516  ...         0         0         0         0         0         0
# 1  24.1755  ...         0         0         0         0         0         0
# 2  31.0305  ...         0         0         0         0         0         0
# 3  37.8795  ...         0         0         0         0         0         0
# 4  39.7614  ...         0         0         0         0         0         0
#
# ...

# %%
new_df = df[['N_total', 'N_bulk', 'N_surface', 'R_avg']]
print(new_df.head(20))
# Out:
#     N_total  N_bulk  N_surface    R_avg
# 0      1599    1014        585  17.3706
# 1      1642    1034        608  17.6061
# 2      4637    3365       1272  25.3692
# 3      7189    5292       1897  29.7011
# 4     11004    8508       2496  34.2831
# 5     13375   10768       2607  36.6334
# 6     13795   11155       2640  37.0108
# 7     13947   11304       2643  37.1672
# 8     14020   11357       2663  37.2103
# 9     14056   11389       2667  37.2467
# 10     1534     966        568  17.1107
# 11     1559     974        585  17.2101
# 12     4356    3099       1257  24.8253
# 13     6550    4675       1875  29.0376
# 14    10175    7748       2427  33.4399
# 15    12393    9842       2551  35.6950
# 16    13207   10590       2617  36.4657
# 17    13543   10937       2606  36.7871
# 18    13713   11079       2634  36.9333
# 19    13791   11151       2640  37.0104

# %%
print("\nMean:")
print(new_df.mean())

print("\nStandard Deviation:")
print(new_df.std())

print("\nQuartiles:")
print(new_df.quantile([0.25, 0.5, 0.75]))
# Out:
# Mean:
# N_total      3476.786500
# N_bulk       2521.550250
# N_surface     955.236250
# R_avg          20.654363
# dtype: float64
#
# Standard Deviation:
# N_total      3679.286769
# N_bulk       2976.232459
# N_surface     721.870220
# R_avg           7.610716
# dtype: float64
#
# Quartiles:
#       N_total   N_bulk  N_surface      R_avg
# 0.25   1061.0   618.75     437.00  15.160725
# 0.50   1867.0  1199.00     666.00  18.629250
# 0.75   4503.0  3183.00    1301.75  25.525125

# %%
plt.figure(figsize=(16, 4))
for i, col in enumerate(new_df.columns):
    plt.subplot(1, 4, i+1)
    plt.hist(new_df[col], bins=30, color='skyblue', edgecolor='black')
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
sns.pairplot(new_df)
plt.show()

# %%
g = sns.PairGrid(new_df)
g.map_upper(sns.histplot)
g.map_diag(sns.histplot, kde=True)
g.map_lower(sns.kdeplot, fill=True)
plt.show()
